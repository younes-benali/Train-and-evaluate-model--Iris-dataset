# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris()
iris

x= pd.DataFrame(iris.data)
y = pd.DataFrame(iris.target)

# Target Lable : 
y[0].unique()
# Out:
# array([0, 1, 2])

# %%
# train_test_split
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(x , y , test_size=0.2 , random_state=42)

# %% [markdown]
# ## KNN-Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier(n_neighbors=3)
KNN.fit(X_train , Y_train)
# Out:
# c:\Users\R\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
Y_pred_train = KNN.predict(X_train)
Y_pred = KNN.predict(X_test)

# %%
# Accuracy score
from sklearn.metrics import accuracy_score
accuracy_score(Y_test , Y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix

# Confusion Matrix
cm = confusion_matrix(Y_test, Y_pred)
cm

sns.heatmap(cm)
# Out:
# <Axes: >

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier(max_depth= 3)
DT.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# Accuracy score
dt_pred = DT.predict(X_test)
accuracy_score(Y_test , dt_pred)
# Out:
# 1.0

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression 

lr = LogisticRegression()
lr.fit(X_train , Y_train)
lr_ypred = lr.predict(X_test)
accuracy_score(lr_ypred , Y_test)
# Out:
# c:\Users\R\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0
